# %%
import pickle

# %%
# 查看各个片段出现的频率

fragment_counts = pickle.load(open('fragment_counts_clean.pkl','rb+'))
print(fragment_counts)

# %%
# 以重原子数目为键，以对应重原子数目的片段为值，进行展示

HeavyNum_Fragments = pickle.load(open('HeavyNum_Fragments.pkl','rb+'))
print(HeavyNum_Fragments)
